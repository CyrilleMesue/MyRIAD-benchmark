# %%
import pandas as pd
import os

# %%
files = os.listdir('ROSMAP') 
files
# Out:
# ['1_featname.csv',
#  '1_te.csv',
#  '1_tr.csv',
#  '2_featname.csv',
#  '2_te.csv',
#  '2_tr.csv',
#  '3_featname.csv',
#  '3_te.csv',
#  '3_tr.csv',
#  'data',
#  'labels_te.csv',
#  'labels_tr.csv',
#  'models',
#  'README.md']

# %%
labels = pd.concat([pd.read_csv('ROSMAP/labels_tr.csv', header=None), 
                    pd.read_csv('ROSMAP/labels_te.csv', header=None)], axis = 0).reset_index(drop=True) 
labels.to_csv('ROSMAP2/labels.csv', header=None, index = False)
labels
# Out:
#        0
# 0    0.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    0.0
# ..   ...
# 346  1.0
# 347  0.0
# 348  0.0
# 349  1.0
# 350  1.0
#
# [351 rows x 1 columns]

# %%
one_data = pd.concat([pd.read_csv('ROSMAP/1_tr.csv', header=None), 
                    pd.read_csv('ROSMAP/1_te.csv', header=None)], axis = 0).reset_index(drop=True) 
one_data.to_csv('ROSMAP2/1_data.csv', header=None, index = False)
one_data
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.181381  0.125337  0.094807  0.480227  0.246111  0.370208  0.214085
# 1    0.132848  0.099462  0.149573  0.487058  0.377940  0.358607  0.300085
# 2    0.111206  0.069999  0.127883  0.412276  0.198039  0.289383  0.200385
# 3    0.085876  0.129139  0.071849  0.473626  0.231430  0.393466  0.184434
# 4    0.068125  0.121434  0.008678  0.453002  0.150118  0.340528  0.201158
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.075482  0.037925  0.080770  0.414871  0.192418  0.309510  0.237900
# 347  0.077265  0.073676  0.107634  0.383032  0.169460  0.229847  0.227279
# 348  0.035597  0.045794  0.143448  0.398780  0.183568  0.278772  0.202311
# 349  0.144581  0.075482  0.090002  0.455681  0.293591  0.360604  0.231430
# 350  0.155456  0.121434  0.104714  0.471631  0.324398  0.355628  0.241474
#
#           7         8         9    ...       190       191       192  \
# ...

# %%
two_data = pd.concat([pd.read_csv('ROSMAP/2_tr.csv', header=None), 
                    pd.read_csv('ROSMAP/2_te.csv', header=None)], axis = 0).reset_index(drop=True) 
two_data.to_csv('ROSMAP2/2_data.csv', header=None, index = False)
two_data
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.598012  0.529952  0.232042  0.704232  0.372624  0.875641  0.613827
# 1    0.586543  0.579997  0.299445  0.664964  0.362864  0.890115  0.512908
# 2    0.634034  0.477586  0.274113  0.713400  0.313916  0.886373  0.659061
# 3    0.557265  0.549105  0.352897  0.685386  0.385889  0.976137  0.573691
# 4    0.587819  0.517650  0.309449  0.692494  0.348508  0.901882  0.620659
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.587064  0.544507  0.335717  0.717406  0.373513  0.887499  0.592954
# 347  0.597947  0.569279  0.313485  0.694064  0.353094  0.800796  0.554376
# 348  0.550135  0.493018  0.247050  0.673338  0.351623  0.879927  0.605780
# 349  0.529054  0.505124  0.295022  0.703988  0.354207  0.847364  0.540725
# 350  0.526849  0.501926  0.268437  0.636161  0.338596  0.826629  0.540336
#
#           7         8         9    ...       190       191       192  \
# ...

# %%
three_data = pd.concat([pd.read_csv('ROSMAP/3_tr.csv', header=None), 
                    pd.read_csv('ROSMAP/3_te.csv', header=None)], axis = 0).reset_index(drop=True) 
three_data.to_csv('ROSMAP2/3_data.csv', header=None, index = False)
three_data
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.814405  0.737390  0.750965  0.826721  0.732031  0.509505  0.941783
# 1    0.833053  0.745852  0.784690  0.833627  0.748797  0.554802  0.939369
# 2    0.783300  0.729652  0.726530  0.832673  0.718069  0.444093  0.945906
# 3    0.806268  0.726243  0.737167  0.838364  0.747425  0.530010  0.951981
# 4    0.803373  0.739387  0.752465  0.821804  0.715556  0.482546  0.927272
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.821659  0.705831  0.740668  0.816380  0.748793  0.536271  0.949251
# 347  0.819375  0.722126  0.730681  0.805196  0.735647  0.446843  0.918457
# 348  0.817341  0.739390  0.739494  0.819699  0.738475  0.418468  0.947598
# 349  0.795896  0.738338  0.763613  0.822731  0.716278  0.479440  0.940050
# 350  0.816905  0.724565  0.719784  0.837038  0.748833  0.480831  0.954793
#
#           7         8         9    ...       190       191       192  \
# ...

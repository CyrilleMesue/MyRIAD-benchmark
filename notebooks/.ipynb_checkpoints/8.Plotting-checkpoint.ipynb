# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
from modules.utils import load_json
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Prepare Data For PCA

# %%
df = pd.read_csv('../BENCHMARKING/Selected_Biomarker_Panels.csv') 
df.rename(columns = {
        'randomforest_feature_importance': 'RF-FI',
        'xgb_feature_importance': 'XGB-FI',
        'rf_permutation_feature_importance': 'RF-PFI',
        'xgb_permutation_feature_importance': 'XGB-PFI'
    }, inplace = True) 
df = df[df.OmicsLevel == 'TripleOmics']
df.head()
# Out:
#              Feature  Cohort   OmicsLevel       OmicsTypes  MOGONET:Ranker  \
# 1800     hsa-miR-30a  ROSMAP  TripleOmics  miRNA+mRNA+Meth             294
# 1801           A2ML1  ROSMAP  TripleOmics  miRNA+mRNA+Meth               1
# 1802  hsa-miR-129-5p  ROSMAP  TripleOmics  miRNA+mRNA+Meth              57
# 1803     hsa-miR-132  ROSMAP  TripleOmics  miRNA+mRNA+Meth              44
# 1804          ARRDC2  ROSMAP  TripleOmics  miRNA+mRNA+Meth             409
#
#       MORE:Ranker  boruta  elasticnet  geom.mean_rank  geom.mean_weight  ...  \
# 1800            1     500           3              64               214  ...
# 1801          317       1          89              31               125  ...
# 1802          192     432           2               2                 1  ...
# 1803           45     438          19               1                 2  ...
# 1804          591      14         253              14                93  ...
#
#       RF-PFI  ridge  rra_rank  shap  stuart_rank  svm_rfe  t_test  ta_weight  \
# 1800     565      3        29   309           51      135     552        109
# 1801     251    138        57   344           39      201      56         37
# 1802     569      2         1     1            1        2       3          1
# 1803       8     17         2     2            2        1       1          2
# 1804     274    211        15    52           14      214       7         36
#
#       XGB-FI  XGB-PFI
# 1800     399      178
# 1801     418      222
# 1802      40        3
# 1803      13        7
# 1804       1      201
#
# [5 rows x 31 columns]

# %%
cohorts = ['ROSMAP', 'BRCA', 'MayoRNASeq'] 
rankers = df.columns[4:]
Selection_Sets = {cohort: {ranker: [] for ranker in rankers} for cohort in cohorts}
for cohort in cohorts:
    df_cohort = df[df.Cohort==cohort]
    all_features = df_cohort.Feature.to_list()
    
    for k in range(10,101,10):
        for ranker in rankers:
            feature_set = df_cohort[df_cohort[ranker] <= k].Feature.to_list() 
            for feat in all_features: 
                if feat in feature_set:
                    Selection_Sets[cohort][ranker].append(1)
                else:
                    Selection_Sets[cohort][ranker].append(0)

# %%
# Save PCA data
for cohort in cohorts:
    df2 = pd.DataFrame(Selection_Sets[cohort])
    df2 = df2[df2.sum(axis=1)>0]
    df2.to_csv(f'../BENCHMARKING/{cohort}_PCA_data.csv', index = False)

# %% [markdown]
# ### Prepare Features For Heatmap

# %%
# select top features for each Cohort: Features that got ranked amongst top 20 in atleast 1 ranker
top_features = {"ROSMAP": [], "BRCA":[], "MayoRNASeq": []}
for cohort in top_features:
    cohort_df = df[df["Cohort"]==cohort]
    for feat in cohort_df.Feature.to_list():
        if sum(cohort_df[cohort_df.Feature==feat].iloc[0,4:] <= 20) > 5:
            top_features[cohort].append(feat) 

for key, value in top_features.items():
    print(key, len(value))
# Out:
# ROSMAP 24
# BRCA 27
# MayoRNASeq 24

# %%
def find_name(x):
    result = None
    for y in names:
        if x in feature_names[names[y]]:  
            result = y
            break
    return result


# prepare Cohort data
cohort_data_filtered = {}
for cohort in top_features:
    cohort_df = df[df["Cohort"]==cohort][df.Feature.isin(top_features[cohort])].drop(columns = df.columns[1:4])
    cohort_df["rank"] = cohort_df.iloc[:,1:].sum(axis=1)
    cohort_df.sort_values(by="rank", ascending = True)
    cohort_df.drop(columns = "rank", inplace = True) 

    feature_names = load_json(f"../results/{cohort}/featurenames.json") 

    if cohort == "ROSMAP" or cohort=="BRCA":
        names = {"miRNA": "1", "mRNA":"2", "Meth":"3"}
    else:
        names = {"Metab": "1", "Prot":"2", "mRNA":"3"}
    cohort_df.insert(0,"FeatureType", cohort_df['Feature'].apply(find_name))
    cohort_df.to_csv(f"../BENCHMARKING/{cohort}_Ranks_data.csv")

# %%
cohort_df
# Out:
#      FeatureType                             Feature  MOGONET:Ranker  \
# 4201       Metab     1,2-dilinoleoyl-GPC (18:2/18:2)               1
# 4202       Metab              1-linoleoyl-GPC (18:2)             403
# 4203       Metab                         stachydrine             197
# 4204       Metab  trigonelline (N'-methylnicotinate)             204
# 4205        mRNA                              E7EVA0             544
# 4206       Metab         N-acetyl-3-methylhistidine*             500
# 4207        Prot                                TBCK              41
# 4212       Metab              trimethylamine N-oxide             205
# 4213       Metab                      2-methylserine             414
# 4218        Prot                               SNTB2              20
# 4220       Metab         1-methyl-5-imidazoleacetate             406
# 4221        Prot                            TRAPPC6A              54
# 4223       Metab                          salicylate             192
# 4224       Metab         1-methyl-5-imidazolelactate             407
# 4226        Prot                      ARHGAP19-SLIT1             329
# 4239       Metab                            12-HHTrE             383
# 4241        Prot                             ANKRD11             396
# 4253        Prot                                CHD3             358
# 4258       Metab                          spermidine             195
# 4259       Metab                    arabitol/xylitol             298
# 4264        mRNA                               LIPA4             489
# 4273        mRNA                                LYAG             514
# 4280        Prot                             ANKRD52             376
# 4288        mRNA                              E9PIM6             532
#
#       MORE:Ranker  boruta  elasticnet  geom.mean_rank  geom.mean_weight  \
# 4201          563       1          16              10                20
# 4202          587       8          13               3                 4
# 4203          393     590           1               1                 1
# 4204          262     597           2               4                14
# 4205          214     171          19              35                33
# 4206           89     292           4               2                 2
# 4207          455     435           3               6                13
# 4212          553     598           9               8                 7
# 4213          302      38          10              11                25
# 4218          117     413         532              18                18
# 4220          545      11          11               7                42
# 4221          516     448         472              13                17
# 4223          495     585          12              25                87
# 4224          448      12           6               5                 3
# 4226          500      84          59              20                11
# 4239          556      26          37              15                29
# 4241          160      74          24               9                 5
# 4253          265     132          38              14                 8
# 4258          134     588          73              23                64
# 4259          408     504           7              12                21
# 4264          278     263           8              24                15
# 4273           79     269          33              19                 9
# 4280          167      75          14              16                16
# 4288          592     175          18              17                22
#
#       lasso  lime  ...  RF-PFI  ridge  rra_rank  shap  stuart_rank  svm_rfe  \
# 4201     14    84  ...      60     21         9    37            9       16
# 4202     15   151  ...      17     39         4     1            3        7
# 4203      3     1  ...      15     13         1     4            1        2
# 4204      5     8  ...     335     12         5    27            5        1
# 4205     10   584  ...       1     61        41   513           44      509
# 4206      6     2  ...     550      1         2     2            2        3
# 4207      1     9  ...     233      8         6   274            6      262
# 4212      2   166  ...      16     31         8     6            8        5
# 4213     13   582  ...      66      2        11    39           12       18
# 4218    488    17  ...     189    379        19     3           19      244
# 4220    405    12  ...     563      5         7    28            7        4
# 4221    516    10  ...     260     74        18    16           18      275
# 4223    404   532  ...     527     20        32    36           25       15
# 4224      9     5  ...     568      3         3     5            4        6
# 4226    150   311  ...     593    390        25    10           22      352
# 4239     25   189  ...     571     27        15    30           13        9
# 4241     26   118  ...     538     67        12     8           10      264
# 4253    152    34  ...     561    260        14     7           14      354
# 4258    408   356  ...      37     15        20    32           20       11
# 4259      7   496  ...      39     30        10    34           11       13
# 4264      8    58  ...     447      9        27   515           24      512
# 4273     46   335  ...     380    133        17    25           16      402
# 4280     11    49  ...     541    117        16   286           15      276
# 4288     17    48  ...     573     47        13   408           17      401
#
#       t_test  ta_weight  XGB-FI  XGB-PFI
# 4201      83         15     413       11
# 4202      27          5      10        2
# 4203       2          1       1       12
# 4204       1          4      51      389
# 4205     231         20     278      594
# 4206       4          2       5        1
# 4207       7          3     467      258
# 4212      10          7      21      590
# 4213      57         11     415       14
# 4218      40         10       4      240
# 4220       3          9     404       19
# 4221       5         23       3      271
# 4223      86         21     412        3
# 4224      13          6      12      596
# 4226      47        150      11      595
# 4239      56         13     406        5
# 4241      20         19       6      242
# 4253      18         16       8      346
# 4258      69         24     408        7
# 4259      71         12     403        9
# 4264     185          8     280      506
# 4273      19         30      23      407
# 4280      29         14     515      272
# 4288      14         31      32      399
#
# [24 rows x 29 columns]
